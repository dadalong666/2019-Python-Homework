# %% [markdown]
# <a href="https://colab.research.google.com/github/dadalong666/2019-Python-Homework/blob/master/test/test_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

a=np.linspace(-10,10,100)
b=np.linspace(-10,10,100)
y=np.cos(a)
z=np.tan(b)
plt.plot(a,y)
plt.plot(b,z)
plt.scatter(b,z)
